# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# #Q1

# %% [raw]
# Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations. Matplotlib’s primary purpose is to provide users with the tools and functionality to represent data graphically, making it easier to analyze and understand. It was originally developed by John D. Hunter in 2003 and is now maintained by a large community of developers.

# %% [raw]
# Matplotlib is a powerful and very popular data visualization library in Python.Data visualization is an essential skill for all data analysts and Matplotlib is one of the most popular libraries for creating visualizations.

# %% [raw]
# Line Graph
# Stem Plot
# Bar chart
# Histograms
# Scatter Plot
# Stack Plot
# Box Plot
# Pie Chart
# Error Plot
# Violin Plot
# 3D Plots

# %% [markdown]
# #Q2

# %% [markdown]
# Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system. The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis. These plots are often called scatter graphs or scatter diagrams.

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y, color='red')
plt.title('Scatter plot of random generated data')
plt.xlabel('X-axis labels')
plt.ylabel('Y-axis labels')
# Out:
# Text(0, 0.5, 'Y-axis labels')

# %% [markdown]
# #Q3

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots (also known as subplots) within a single figure. This is particularly useful when you want to compare different data visualizations side by side or when you have multiple related plots that you want to present together in a grid layout

# %% [raw]
# Key Reasons for Using subplot():
# Multiple Plots in One Figure:
#
# When you want to display more than one plot in a single figure, subplot() allows you to organize them in rows and columns. For example, you can create a 2x2 grid of plots, showing four different visualizations together.
# Comparisons:
#
# By displaying multiple subplots in a single figure, you can easily compare different datasets or visualizations. For instance, you could show how different statistical measures change over time in adjacent plots.
# Efficient Use of Space:
#
# Instead of creating separate figures for each plot, which might clutter your workspace or report, subplot() allows you to place multiple plots in a single, cohesive figure, making better use of the available space.
# Consistent Formatting:
#
# Subplots within the same figure can share axes, labels, titles, and other formatting features, ensuring a consistent look and feel across all the plots.

# %%
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.plot([0, 1, 2, 3, 4, 5],[0, 100, 200, 300, 400, 500])
plt.title("1st plot")

plt.subplot(2,2,2)
plt.plot([0, 1, 2, 3, 4, 5],[50, 20, 40, 20, 60, 70])
plt.title("2nd plot")

plt.subplot(2,2,3)
plt.plot([0, 1, 2, 3, 4, 5],[10, 20, 30, 40, 50, 60])
plt.title("3rd plot")

plt.subplot(2,2,4)
plt.plot([0, 1, 2, 3, 4, 5],[200, 350, 250, 550, 450, 150])
plt.title("4th plot")
# Out:
# Text(0.5, 1.0, '4th plot')

# %% [markdown]
# #Q4

# %% [raw]
# A bar plot, also known as a bar chart, is a type of data visualization used to represent categorical data with rectangular bars. The length or height of each bar is proportional to the value it represents. Bar plots are commonly used to compare different categories, show frequency distributions, or illustrate relationships between variables.

# %% [raw]
# Key Features of a Bar Plot:
# Bars:
#
# The bars can be displayed either vertically (with bars extending upward) or horizontally (with bars extending sideways).
# The length or height of each bar represents the magnitude of the data value for that category.
# Axes:
#
# X-axis: Typically represents the categories or groups being compared. If the bars are vertical, the categories are along the x-axis. If the bars are horizontal, the categories are along the y-axis.
# Y-axis: Represents the values corresponding to each category. If the bars are vertical, the values are along the y-axis. If the bars are horizontal, the values are along the x-axis.
# Categories:
#
# Each bar corresponds to a different category or group. These categories are typically discrete and non-overlapping.
# Spacing:
#
# Bars are typically spaced evenly apart to allow for easy comparison between categories.

# %% [markdown]
# Bar plots are used primarily for the following reasons:
#
# Comparison of Categories: They provide a clear visual comparison between different categories or groups, making it easy to see which categories have higher or lower values.
#
# Simple Visualization: Bar plots are straightforward and easy to interpret, making them accessible for a wide audience.
#
# Trend Identification: They help in identifying trends over time when comparing data across different periods.
#
# Frequency Distribution: Bar plots can effectively show the frequency or count of categories within a dataset.
#
# Highlighting Differences: They are useful for emphasizing significant differences or outliers among categories.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.title('Company Profits (Vertical Bar Plot)')
plt.xlabel('Company names')
plt.ylabel('Company profit')
# Out:
# Text(0, 0.5, 'Company profit')

# %%
plt.barh(company, profit, color='orange')
plt.title('Company Profits (Horizontal Bar Plot)')
plt.xlabel('Profit in USD')
plt.ylabel('Company')
# Out:
# Text(0, 0.5, 'Company')

# %%
#Q5

# %% [raw]
# A box plot, also known as a box-and-whisker plot, is a standardized way of displaying the distribution of data based on a five-number summary: the minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. It provides a visual summary of data, allowing you to easily identify the central tendency, variability, and potential outliers.

# %% [raw]
# When to Use a Box Plot:
# Comparing Distributions:
#
# Box plots are particularly useful for comparing the distributions of multiple datasets or groups. You can easily compare the medians, spreads, and ranges of different datasets.
# Identifying Outliers:
#
# Box plots help in identifying outliers, which are data points that fall significantly outside the typical range of the data.
# Visualizing Skewness:
#
# The position of the median within the box and the length of the whiskers can indicate the skewness of the data. For example, if the median is closer to the bottom of the box, the data may be skewed to the lower end.
# Summarizing Data:
#
# Box plots provide a quick summary of the key statistics of a dataset, including the median, range, and variability.

# %% [raw]
# Box plots are used to effectively visualize and compare data distributions, identify outliers, understand data spread, and summarize key statistics, making them a valuable tool in data analysis and presentation.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7df76f95a020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7df76f95a560>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7df76f959e70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7df76f95aaa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7df76f95ad40>],
#  'means': []}

# %%
plt.boxplot(box2,color="pink")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plt.boxplot(box2,color="pink")
#
# TypeError: boxplot() got an unexpected keyword argument 'color'
